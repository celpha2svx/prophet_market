# %% [markdown]
# # Model Training, Testing and evaluation

# %% [markdown]
# ## Load Data

# %%
import pandas as pd 

df = pd.read_csv('aapl_features.csv')
df.head()
# Out:
#                         date symbol       close       sma_5  sma_20  sma_50  \
# 0  2025-04-15 00:00:00-04:00   AAPL  201.646423         NaN     NaN     NaN
# 1  2025-04-16 00:00:00-04:00   AAPL  193.795639         NaN     NaN     NaN
# 2  2025-04-17 00:00:00-04:00   AAPL  196.499023         NaN     NaN     NaN
# 3  2025-04-21 00:00:00-04:00   AAPL  192.688339         NaN     NaN     NaN
# 4  2025-04-22 00:00:00-04:00   AAPL  199.252289  196.776343     NaN     NaN
#
#        ema_12      ema_26  rsi      macd  macd_signal  macd_histogram  atr  \
# 0  201.646423  201.646423  NaN  0.000000     0.000000        0.000000  NaN
# 1  200.438610  201.064884  NaN -0.626273    -0.125255       -0.501019  NaN
# 2  199.832520  200.726672  NaN -0.894152    -0.279034       -0.615118  NaN
# 3  198.733415  200.131240  NaN -1.397825    -0.502792       -0.895032  NaN
# 4  198.813242  200.066132  NaN -1.252890    -0.652812       -0.600079  NaN
#
# ...
